# %% [markdown]
# # Medicare Fraud - Class Imbalance Exploratory Data Analysis
#
# Mustapha Mbengue, Peyton Nash, Bradley Stoller, Kyler Rosen
#
# 3/9/25
#
# Purpose: Conducts exploratory data analysis on the class imbalance.

# %% [markdown]
# ### Setup

# %%
# Load libraries
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read in the data
df = pd.read_csv('data/train_data.csv')
df.head()
# Out:
# /var/folders/mf/8c9q6j514k1_fgpgs5221sch0000gn/T/ipykernel_44450/4051610974.py:4: DtypeWarning: Columns (9,12,13,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path_label)
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# 4                   10000          PHY379376          PHY398258
#
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Create a pie chart of potential fraud
plt.title('Percentage of Potentially Fraudulent Observations')
plt.pie(df['PotentialFraud'].value_counts(), autopct='%1.1f%%', labels=df['PotentialFraud'].value_counts().index, startangle=90)
plt.legend()
plt.show()

# %%
fraud_counts = df['PotentialFraud'].value_counts()
plt.figure(figsize=(8, 4))
plt.pie(
    fraud_counts, 
    labels= ['Fraud', 'No Fraud'], 
    autopct='%1.1f%%', 
    startangle=90, 
    colors=['#ff9999','#66b3ff'], 
    wedgeprops={'edgecolor': 'black'}
)
plt.title('Distribution of Potential Fraud Cases', fontsize= 16, fontweight= 'bold')
plt.show()
