# %%
# Load libraries
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/train_data.csv')
df.head()
# Out:
# /var/folders/6c/lknfcl0j3lb3skfwn995xkym0000gn/T/ipykernel_65099/2142248852.py:1: DtypeWarning: Columns (9,12,13,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/train_data.csv')
#       BeneID   ClaimID ClaimStartDt  ClaimEndDt  Provider  \
# 0  BENE11001  CLM46614   2009-04-12  2009-04-18  PRV55912
# 1  BENE11001  CLM66048   2009-08-31  2009-09-02  PRV55907
# 2  BENE11001  CLM68358   2009-09-17  2009-09-20  PRV56046
# 3  BENE11011  CLM38412   2009-02-14  2009-02-22  PRV52405
# 4  BENE11014  CLM63689   2009-08-13  2009-08-30  PRV56614
#
#    InscClaimAmtReimbursed AttendingPhysician OperatingPhysician  \
# 0                   26000          PHY390922                NaN
# 1                    5000          PHY318495          PHY318495
# 2                    5000          PHY372395                NaN
# 3                    5000          PHY369659          PHY392961
# ...

# %%
plt.pie(df['PotentialFraud'].value_counts())
plt.show()

# %%
# Count occurrences of each category
fraud_counts = df['PotentialFraud'].value_counts()

# Plot the pie chart
plt.figure(figsize=(6, 6))
plt.pie(fraud_counts, labels= ['Fraud', 'No Fraud'], autopct='%1.1f%%', startangle=90, 
        colors=['#ff9999','#66b3ff'], wedgeprops={'edgecolor': 'black'})

# Add a title
plt.title('Distribution of Potential Fraud Cases')

# Show the plot
plt.show()
